# %% [markdown]
# ### **Meteostat API testing and familiarisation**

# %% [markdown]
# From online, the following should be done to obtain an API key for Meteostat:
# 1.) Sign up to RapidAPI
# 2.) Subscribe to Meteostat API
# 3.) Meteostat API documentation > Header Parameters > X-RapidAPI-Key

# %% [markdown]
# Below I'm familiarising myself with the meteostat API and APIs in general. Referencing meteostat documentation (https://dev.meteostat.net/api/#sign-up), RapidAPI documentation (https://rapidapi.com/meteostat/api/meteostat), and this notebook: https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/API_tutorial.ipynb#scrollTo=1EUYsUr3IPd2

# %%
import requests

url = "https://meteostat.p.rapidapi.com/stations/hourly"

querystring = {"station":"10637","start":"2020-01-01","end":"2020-01-02","tz":"Europe/Berlin"}

headers = {
	"X-RapidAPI-Key": "1150bfcd8fmsh647a90b1a29044cp17e796jsn29213ab6b8c9",
	"X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'meta': {'generated': '2023-09-01 09:08:29'}, 'data': [{'time': '2020-01-01 00:00:00', 'temp': 0.3, 'dwpt': -1.5, 'rhum': 88.0, 'prcp': 0.0, 'snow': None, 'wdir': 40.0, 'wspd': 8.6, 'wpgt': 13.0, 'pres': 1036.9, 'tsun': 0, 'coco': 3}, {'time': '2020-01-01 01:00:00', 'temp': 0.0, 'dwpt': -1.4, 'rhum': 90.0, 'prcp': 0.0, 'snow': 0.0, 'wdir': 40.0, 'wspd': 9.7, 'wpgt': 15.0, 'pres': 1036.5, 'tsun': 0, 'coco': 3}, {'time': '2020-01-01 02:00:00', 'temp': 0.1, 'dwpt': -1.3, 'rhum': 90.0, 'prcp': 0.0, 'snow': None, 'wdir': 20.0, 'wspd': 10.1, 'wpgt': 15.0, 'pres': 1036.3, 'tsun': 0, 'coco': 5}, {'time': '2020-01-01 03:00:00', 'temp': -1.1, 'dwpt': -2.2, 'rhum': 92.0, 'prcp': 0.0, 'snow': None, 'wdir': 70.0, 'wspd': 7.9, 'wpgt': 13.0, 'pres': 1036.2, 'tsun': 0, 'coco': 2}, {'time': '2020-01-01 04:00:00', 'temp': -0.4, 'dwpt': -1.4, 'rhum': 93.0, 'prcp': 0.0, 'snow': None, 'wdir': 80.0, 'wspd': 5.8, 'wpgt': 11.0, 'pres': 1035.7, 'tsun': 0, 'coco': 3}, {'time': '2020-01-01 05:00:00', 'temp': 
# ...

# %%
payload = response.json()

# %%
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(payload)
# Out:
# {'data': [{'coco': 3,
#            'dwpt': -1.5,
#            'prcp': 0.0,
#            'pres': 1036.9,
#            'rhum': 88.0,
#            'snow': None,
#            'temp': 0.3,
#            'time': '2020-01-01 00:00:00',
#            'tsun': 0,
#            'wdir': 40.0,
#            'wpgt': 13.0,
#            'wspd': 8.6},
#           {'coco': 3,
#            'dwpt': -1.4,
#            'prcp': 0.0,
#            'pres': 1036.5,
#            'rhum': 90.0,
#            'snow': 0.0,
#            'temp': 0.0,
#            'time': '2020-01-01 01:00:00',
#            'tsun': 0,
#            'wdir': 40.0,
#            'wpgt': 15.0,
#            'wspd': 9.7},
#           {'coco': 5,
#            'dwpt': -1.3,
#            'prcp': 0.0,
#            'pres': 1036.3,
#            'rhum': 90.0,
#            'snow': None,
#            'temp': 0.1,
#            'time': '2020-01-01 02:00:00',
#            'tsun': 0,
#            'wdir': 20.0,
#            'wpgt': 15.0,
# ...

# %%
payload['data']
# Out:
# [{'time': '2020-01-01 00:00:00',
#   'temp': 0.3,
#   'dwpt': -1.5,
#   'rhum': 88.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 40.0,
#   'wspd': 8.6,
#   'wpgt': 13.0,
#   'pres': 1036.9,
#   'tsun': 0,
#   'coco': 3},
#  {'time': '2020-01-01 01:00:00',
#   'temp': 0.0,
#   'dwpt': -1.4,
#   'rhum': 90.0,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'wdir': 40.0,
#   'wspd': 9.7,
#   'wpgt': 15.0,
#   'pres': 1036.5,
#   'tsun': 0,
#   'coco': 3},
#  {'time': '2020-01-01 02:00:00',
#   'temp': 0.1,
#   'dwpt': -1.3,
#   'rhum': 90.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 20.0,
#   'wspd': 10.1,
#   'wpgt': 15.0,
#   'pres': 1036.3,
#   'tsun': 0,
#   'coco': 5},
#  {'time': '2020-01-01 03:00:00',
#   'temp': -1.1,
#   'dwpt': -2.2,
#   'rhum': 92.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 70.0,
#   'wspd': 7.9,
#   'wpgt': 13.0,
#   'pres': 1036.2,
#   'tsun': 0,
#   'coco': 2},
#  {'time': '2020-01-01 04:00:00',
#   'temp': -0.4,
#   'dwpt': -1.4,
#   'rhum': 93.0,
# ...

# %% [markdown]
# Now visualising the data in a Pandas dataframe

# %%
import pandas as pd

df = pd.DataFrame(payload['data'])
df
# Out:
#                    time  temp  dwpt   rhum  prcp  snow   wdir  wspd  wpgt  \
# 0   2020-01-01 00:00:00   0.3  -1.5   88.0   0.0   NaN   40.0   8.6  13.0
# 1   2020-01-01 01:00:00   0.0  -1.4   90.0   0.0   0.0   40.0   9.7  15.0
# 2   2020-01-01 02:00:00   0.1  -1.3   90.0   0.0   NaN   20.0  10.1  15.0
# 3   2020-01-01 03:00:00  -1.1  -2.2   92.0   0.0   NaN   70.0   7.9  13.0
# 4   2020-01-01 04:00:00  -0.4  -1.4   93.0   0.0   NaN   80.0   5.8  11.0
# 5   2020-01-01 05:00:00   0.2  -1.2   90.0   0.0   NaN   50.0   7.2  11.0
# 6   2020-01-01 06:00:00  -1.5  -2.8   91.0   0.0   NaN   50.0   8.3  13.0
# 7   2020-01-01 07:00:00  -1.2  -2.3   92.0   0.0   0.0   50.0   9.7  15.0
# 8   2020-01-01 08:00:00  -1.4  -2.5   92.0   0.0   NaN   10.0  10.4  15.0
# 9   2020-01-01 09:00:00  -1.2  -2.5   91.0   0.0   NaN   30.0  11.2  18.0
# 10  2020-01-01 10:00:00  -0.5  -2.4   87.0   0.0   NaN   30.0  10.8  17.0
# 11  2020-01-01 11:00:00   0.6  -2.1   82.0   0.0   NaN   20.0  12.2  21.0
# ...
